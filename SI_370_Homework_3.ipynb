# %% [markdown]
# # SI 370 Homework #3
#
# ## Taylor Swift songs
#
# Last updated 2023-10-04

# %% [markdown]
# The dataset for this assignment is from https://www.kaggle.com/datasets/jarredpriester/taylor-swift-spotify-dataset/data.
#
# **NOTE**: Use the dataset from Canvas rather than the dataset from Kaggle, which is updated frequently and may change while you are completing this assignment.
#
# This dataset consist of data from Spotify's API on all albums listed on Spotify for Taylor Swift. I set up the dataset to update monthly so that if any albums get added it will get added to the dataset too. At first it may look like there are song duplicates but I checked and all song IDs are unique.
#
# The columns in this dataset are:
#
# name - the name of the song
#
# album - the name of the album
#
# release_date - the day month and year the album was released
#
# track number - the order the song appears on the album
#
# id - the Spotify id for the song
#
# uri - the Spotify uri for the song
#
# acousticness - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# danceability - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# energy - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# instrumentalness - Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# liveness - Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# loudness - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# speechiness - detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# tempo - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# valence - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# popularity - the popularity of the song from 0 to 100
#
# duration_ms - The duration of the track in milliseconds.

# %% [markdown]
# We are going to refer to the tracks' properties of danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, and valence as "features" of the tracks.

# %% [markdown]
# Each of the questions is worth the same number of points, except for the final bonus question, which is worth up to an additional 1 point (out of 20).  Points will be allocated according to the following rubric:
#
# - 90-100%: Question is correctly and completely answered.  Answer consists of well-written code that conforms to [PEP 8](https://www.python.org/dev/peps/pep-0008/) guidelines and is
# accompanied by a written interpretation in a Markdown block.  Written interpretation does not contain spelling, grammar or stylistic errors (see [Strunk & White](https://drive.google.com/file/d/1L0P7xJwjUGBvyb49mL3dw1Bt7hzRTiTl/view?usp=sharing) for a detailed specifications).  Minor problems, such as formatting, incorrect submissions, missing names, etc. will result in less than 100%.
# - 75-85% : Answer is mostly complete and correct; two or fewer noticeable omissions or errors.  Minor stylistic flaws, either in code or in
# written interpretation.
# - 50-70%: Answer has significant omissions or errors; Noticeable departure from PEP-8 guildelines and/or moderate spelling, grammar, or style issues
# in written interpretations.
# - 25-45%: Question is perfunctorily attempted.  Substantial parts are missing or incorrect.
# - 0 points: Question not attempted.
#
# Be sure to include interpretations of your results for each question.

# %% [markdown]
# Q1: Show the distribution of the popularity of the songs.  Then exclude the songs that are from karaoke albums (i.e., the album name contains "karaoke").  Show the distribution of the popularity of the songs.  What is the difference between the two distributions?

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

swift=pd.read_csv('/Users/sarrahahmed/Desktop/si370fa23-student-main/data/taylor_swift_spotify.csv')

swift.head()
# Out:
#    Unnamed: 0                                    name  \
# 0           0                           Lavender Haze
# 1           1                                  Maroon
# 2           2                               Anti-Hero
# 3           3  Snow On The Beach (feat. Lana Del Rey)
# 4           4                 You're On Your Own, Kid
#
#                      album release_date  track_number                      id  \
# 0  Midnights (3am Edition)   2022-10-22             1  4g2c7NoTWAOSYDy44l9nub
# 1  Midnights (3am Edition)   2022-10-22             2  199E1RRrVmVTQqBXih5qRC
# 2  Midnights (3am Edition)   2022-10-22             3  02Zkkf2zMkwRGQjZ7T4p8f
# 3  Midnights (3am Edition)   2022-10-22             4  6ADDIJxxqzM9LMpm78yzQG
# 4  Midnights (3am Edition)   2022-10-22             5  7gVWKBcfIW93YxNBi3ApIE
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:4g2c7NoTWAOSYDy44l9nub        0.2040         0.735   0.444
# 1  spotify:track:199E1RRrVmVTQqBXih5qRC        0.0593         0.658   0.378
# 2  spotify:track:02Zkkf2zMkwRGQjZ7T4p8f        0.1330         0.638   0.634
# 3  spotify:track:6ADDIJxxqzM9LMpm78yzQG        0.7350         0.659   0.323
# 4  spotify:track:7gVWKBcfIW93YxNBi3ApIE        0.4160         0.694   0.380
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.001200    0.1700   -10.519       0.0684   97.038   0.0984
# 1          0.000000    0.0976    -8.300       0.0379  108.034   0.0382
# 2          0.000001    0.1520    -6.582       0.0457   96.953   0.5190
# 3          0.003210    0.1160   -13.425       0.0436  110.007   0.1540
# 4          0.000008    0.1260   -10.307       0.0614  120.044   0.3760
#
#    popularity  duration_ms
# 0          77       202395
# 1          76       218270
# 2          77       200690
# 3          74       256124
# 4          76       194206

# %%
#dist 1
sns.histplot(swift['popularity'])
plt.show()

# %%
df_no_karaoke = swift[~swift['album'].str.contains('karaoke', case=False, na=False)]


sns.histplot(df_no_karaoke['popularity'])
plt.show()

# %% [markdown]
# Interpretation:

# %% [markdown]
# when we plot the distribution of popularity for the df with no karaoke albums, we see that far less albumms have a popularity of 0 and most albums have a popuarity of 50. the karaoke albums skew the popularity distribution of albums, likely because they are less popular

# %%
sns.barplot(x='album', y='popularity', data=df_no_karaoke)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### <font color='magenta'>IMPORTANT NOTE: the remainder of the questions are based on the songs that are NOT from karaoke albums.</font>

# %% [markdown]
# Q2: Report the average track duration for each album.  You answer should be in mm:ss (minutes:seconds) format rather than the milliseconds that are reported in the original dataset.

# %%
df_no_karaoke['time_min_sec'] = pd.to_datetime(df_no_karaoke['duration_ms'], unit='ms').dt.strftime('%M:%S')


#dont actually need this
# Out:
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/3634504081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_karaoke['time_min_sec'] = pd.to_datetime(df_no_karaoke['duration_ms'], unit='ms').dt.strftime('%M:%S')

# %%
df_album_avg = df_no_karaoke.groupby('album')['duration_ms'].mean()


df_album_avg = pd.to_datetime(df_album_avg, unit='ms').dt.strftime('%M:%S')



#group by album
#edit the group by so that it is in minutes and seconds

# %%
df_album_avg.sort_values(ascending=False, inplace=True)

df_album_avg
# Out:
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/1327349628.py:1: SettingWithCopyWarning: modifications to a method of a datetimelike object are not supported and are discarded. Change values on the original.
#   df_album_avg.sort_values(ascending=False, inplace=True)
# album
# Speak Now World Tour Live                                                              04:57
# Speak Now (US Version)                                                                 04:47
# Speak Now                                                                              04:47
# Speak Now (Japanese Version)                                                           04:46
# Speak Now (Deluxe Package)                                                             04:35
# Speak Now (Deluxe Edition)                                                             04:35
# Red (Taylor's Version)                                                                 04:21
# Fearless Platinum Edition                                                              04:10
# Fearless (Platinum Edition)                                                            04:10
# Red (Deluxe Edition)                                                                   04:06
# Fearless (Taylor's Version)                                                            04:05
# Red                                                                                    04:04
# evermore (deluxe version)                                                              04:03
# evermore                                                                               04:03
# reputation Stadium Tour Surprise Song Playlist                                         04:02
# Fearless                                                                               04:00
# Fearless (International Version)                                                       04:00
# folklore                                                                               03:58
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    03:57
# folklore (deluxe version)                                                              03:56
# 1989                                                                                   03:45
# reputation                                                                             03:43
# 1989 (Deluxe Edition)                                                                  03:41
# 1989 (Deluxe)                                                                          03:37
# Taylor Swift                                                                           03:33
# Live From Clear Channel Stripped 2008                                                  03:29
# Midnights (3am Edition)                                                                03:28
# Lover                                                                                  03:26
# Midnights                                                                              03:23
# Speak Now (Big Machine Radio Release Special)                                          02:59
# reputation (Big Machine Radio Release Special)                                         02:44
# Red (Big Machine Radio Release Special)                                                02:38
# 1989 (Big Machine Radio Release Special)                                               02:37
# Fearless (Big Machine Radio Release Special)                                           02:33
# Taylor Swift (Big Machine Radio Release Special)                                       02:26
# Name: duration_ms, dtype: object

# %% [markdown]
# the average duration falls between 2 and 5 minutes as we can see from the sorted series

# %% [markdown]
# Q3: Show a heatmap of the correlations between the features.  Use a diverging colormap with white in the middle (i.e. white at a correlation of 0.0).

# %%
corr = df_no_karaoke.corr()

corr
# Out:
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/110218122.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_no_karaoke.corr()
#                   Unnamed: 0  track_number  acousticness  danceability  \
# Unnamed: 0          1.000000     -0.023027     -0.278065      0.026984
# track_number       -0.023027      1.000000      0.070222     -0.005213
# acousticness       -0.278065      0.070222      1.000000     -0.022470
# danceability        0.026984     -0.005213     -0.022470      1.000000
# energy              0.216924     -0.072316     -0.756873     -0.073056
# instrumentalness    0.017668     -0.035339     -0.055139     -0.021544
# liveness            0.156911      0.014847     -0.063505     -0.034634
# loudness            0.365714     -0.103962     -0.777471     -0.138921
# speechiness         0.131202      0.154341      0.404049      0.350922
# tempo               0.026592      0.041330     -0.171262     -0.240997
# valence             0.142066      0.012831     -0.072812      0.415063
# popularity         -0.316066     -0.174036     -0.127021     -0.087231
# duration_ms        -0.052318     -0.062663     -0.283706     -0.417011
#
#                     energy  instrumentalness  liveness  loudness  speechiness  \
# Unnamed: 0        0.216924          0.017668  0.156911  0.365714     0.131202
# track_number     -0.072316         -0.035339  0.014847 -0.103962     0.154341
# acousticness     -0.756873         -0.055139 -0.063505 -0.777471     0.404049
# danceability     -0.073056         -0.021544 -0.034634 -0.138921     0.350922
# energy            1.000000          0.010537  0.074975  0.817729    -0.409169
# instrumentalness  0.010537          1.000000 -0.038933 -0.098910    -0.052273
# liveness          0.074975         -0.038933  1.000000  0.007121     0.163912
# loudness          0.817729         -0.098910  0.007121  1.000000    -0.549766
# speechiness      -0.409169         -0.052273  0.163912 -0.549766     1.000000
# tempo             0.266027         -0.026519 -0.030562  0.249124    -0.210773
# valence           0.306586         -0.024569  0.023628  0.108877     0.298715
# popularity        0.125911         -0.197000 -0.096685  0.160417    -0.337974
# duration_ms       0.207158          0.038490 -0.076222  0.378038    -0.747227
#
#                      tempo   valence  popularity  duration_ms
# Unnamed: 0        0.026592  0.142066   -0.316066    -0.052318
# track_number      0.041330  0.012831   -0.174036    -0.062663
# acousticness     -0.171262 -0.072812   -0.127021    -0.283706
# danceability     -0.240997  0.415063   -0.087231    -0.417011
# energy            0.266027  0.306586    0.125911     0.207158
# instrumentalness -0.026519 -0.024569   -0.197000     0.038490
# liveness         -0.030562  0.023628   -0.096685    -0.076222
# loudness          0.249124  0.108877    0.160417     0.378038
# speechiness      -0.210773  0.298715   -0.337974    -0.747227
# tempo             1.000000 -0.002296    0.076331     0.149821
# valence          -0.002296  1.000000   -0.102781    -0.444580
# popularity        0.076331 -0.102781    1.000000     0.220585
# duration_ms       0.149821 -0.444580    0.220585     1.000000

# %%
sns.heatmap(corr, center=0, fmt=".2f", cmap='RdBu', annot=True)
plt.show()

# %% [markdown]
# this is a map of each feature's correlation to another with higher positive correlations marked in blue and higher negative correlations marked in red. currently, a high correlation of 1 is seen among categories and themselves, obviously. high positive correlations are also seen between energy and loudness

# %% [markdown]
# Q4: List the top 5 correlations between the features of the songs.

# %%
s = corr.abs().unstack().sort_values(ascending=False)


df_corr = pd.DataFrame(s, columns=['Correlation'])
df_corr = df_corr.reset_index()

df_corr.columns = ['Feature 1','Feature 2', 'Correlation']

df_corr = df_corr[df_corr['Feature 1'] != df_corr['Feature 2']]

# Remove duplicates
df_corr = df_corr.drop_duplicates(subset=['Correlation'])

# Print top 5 correlations
print(df_corr.head(5))
# Out:
#        Feature 1     Feature 2  Correlation
# 12        energy      loudness     0.817729
# 14  acousticness      loudness     0.777471
# 16        energy  acousticness     0.756873
# 18   speechiness   duration_ms     0.747227
# 20      loudness   speechiness     0.549766

# %% [markdown]
# the 5 top correlations are between energy and loudness, acoustic and loudness, energy and acousticness, speechiness and duration, and loudness and speechidness

# %% [markdown]
# Q5: Does the position of the track on the album (i.e. track number) have an effect on the popularity of the song?  Use both visual and statistical evidence to support your answer.

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_no_karaoke['track_number'], df_no_karaoke['popularity'], marker='o')
plt.title('Track Popularity vs. Track Number')
plt.xlabel('Track Number')
plt.ylabel('Popularity')
plt.grid(True)
plt.show()

# %%
import statsmodels.api as sm


X = sm.add_constant(df_no_karaoke['track_number'])
model = sm.OLS(df_no_karaoke['popularity'], X).fit()

print(model.summary())

plt.scatter(df_no_karaoke['track_number'], df_no_karaoke['popularity'])
plt.plot(df_no_karaoke['track_number'], model.predict(X), color='red', linewidth=2)
plt.title('Regression Analysis: Track Popularity vs. Track Number')
plt.xlabel('Track Number')
plt.ylabel('Popularity')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             popularity   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     33.51
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):           9.28e-09
# Time:                        19:45:29   Log-Likelihood:                -4732.3
# No. Observations:                1075   AIC:                             9469.
# Df Residuals:                    1073   BIC:                             9479.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           52.3687      1.066     49.111      0.000      50.276      54.461
# track_number    -0.4624      0.080     -5.789      0.000      -0.619      -0.306
# ==============================================================================
# Omnibus:                      115.980   Durbin-Watson:                   0.414
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.834
# Skew:                          -0.106   Prob(JB):                     2.73e-08
# Kurtosis:                       2.144   Cond. No.                         23.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_value = model.pvalues['track_number']
p_value
# Out:
# 9.280428374315366e-09

# %% [markdown]
# According to the p-value there is a statistical significance in the relationship between track number and popularity however the visual evidence is not as persuasive. The first plot looks like a complete mess and does not allow us to deduce much about the relationship between the two variables apart from the outliers. the regression plot is easier to break down yet we see that popularity ranges broadly for tracks 1-18 although popularity definitely decreases after tracks 20, but this could also be because taylor swift may not have more than 20 songs on every album

# %% [markdown]
# Q6: Are popular songs more danceable?
# Divide the songs into popular (i.e. those with a popularity rating of 60 or higher) and less popular (i.e. those with a popularity rating of less than 60).
# Conduct an ANOVA test for the two groups of data based on danceability feature. Are they statistically significant?

# %%
df_no_karaoke['popularity_group'] = pd.cut(df_no_karaoke['popularity'], bins=[0, 60, float('inf')], labels=['less_popular', 'popular'])
# Out:
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/3842672059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_karaoke['popularity_group'] = pd.cut(df_no_karaoke['popularity'], bins=[0, 60, float('inf')], labels=['less_popular', 'popular'])

# %%
from statsmodels.formula.api import ols


df_no_karaoke['popularity_group'] = df_no_karaoke['popularity_group'].astype('category')

popularity_lm = ols('danceability ~ C(popularity_group)', data=df_no_karaoke).fit()
table = sm.stats.anova_lm(popularity_lm, typ=2)

print(table)
# Out:
#                         sum_sq      df         F    PR(>F)
# C(popularity_group)   0.033725     1.0  2.668959  0.102618
# Residual             13.482790  1067.0       NaN       NaN
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/382082620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_karaoke['popularity_group'] = pd.cut(df_no_karaoke['popularity'], bins=[0, 60, float('inf')], labels=['less_popular', 'popular'])
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/382082620.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_karaoke['popularity_group'] = df_no_karaoke['popularity_group'].astype('category')

# %% [markdown]
# The p-value is 0.102618, which is greater than the common significance level of 0.05, so we fail to reject the null hypothesis. This suggests that there isn't enough evidence to conclude that there is a significant difference in danceability between the 'less_popular' and 'popular' groups.

# %% [markdown]
# Q7: Create a regression model with "popularity" as the dependent variable and "liveness" as the predictor variable.
# Report the following:
# 1. Coefficient of determination (i.e. $r^2$)
# 2. Whether the regression is statistically significant
# 3. An estimate for the value of "popularity" when the value of "liveness" is 0.22.

# %%
X = sm.add_constant(df_no_karaoke['liveness'])


model = sm.OLS(df_no_karaoke['popularity'], X).fit()
print(model.summary())

r_squared = model.rsquared
p_value = model.pvalues['liveness']


liveness_value = 0.22
popularity_estimate = model.predict([1, liveness_value])[0]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             popularity   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.12
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):            0.00150
# Time:                        20:08:16   Log-Likelihood:                -4743.8
# No. Observations:                1075   AIC:                             9492.
# Df Residuals:                    1073   BIC:                             9502.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         49.8667      1.017     49.048      0.000      47.872      51.862
# liveness     -16.1986      5.091     -3.182      0.002     -26.188      -6.210
# ==============================================================================
# Omnibus:                      183.152   Durbin-Watson:                   0.400
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.318
# Skew:                          -0.056   Prob(JB):                     1.07e-09
# Kurtosis:                       2.046   Cond. No.                         8.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Coefficient of determination (r^2): 0.009347904256833739
# P-value for liveness: 0.0015047537078467586
# The regression is statistically significant.

# %% [markdown]
# Q8: Due to intellectual property conflicts, Taylor Swift re-recorded some of her earlier albums, including `Fearless`, `Red` and `Speak Now`.  We assume that re-recording her early albums will allow Taylor Swift to reclaim her artistry control, revisit the songs and make any changes she wants. Therefore, we want to see whether the new songs are more loved by the audiences by looking at the popularity score.
#
# * The re-recorded ones have `(Taylor’s version)` at the end of the album name.
# * We will ignore the Speak Now World Tour Live version. Therefore there are 5 albums as original and 3 as re-recorded
#
# a) Create a visualization that shows the distribution of popularity scores of original vs. re-recorded songs.  There are multiple visualizations that would be appropriate here.  You can choose any of them.  At a minimum, you should create one visualization.  Creating additional ones can earn you additional points.
#
# b) Is there a statistically significant difference between the popularity scores of the original and re-recorded songs?  If so, which one is more popular?  How much more popular is it, on average?

# %%
df_no_karaoke.album.value_counts()
# Out:
# folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]    68
# Fearless                                                                               63
# Red (Taylor's Version)                                                                 60
# reputation Stadium Tour Surprise Song Playlist                                         46
# evermore                                                                               45
# Red (Deluxe Edition)                                                                   44
# Midnights (3am Edition)                                                                40
# 1989                                                                                   39
# 1989 (Deluxe)                                                                          38
# evermore (deluxe version)                                                              34
# folklore (deluxe version)                                                              34
# 1989 (Deluxe Edition)                                                                  34
# Red (Big Machine Radio Release Special)                                                32
# Red                                                                                    32
# folklore                                                                               32
# reputation (Big Machine Radio Release Special)                                         31
# Taylor Swift (Big Machine Radio Release Special)                                       30
# Taylor Swift                                                                           30
# Speak Now                                                                              28
# Speak Now (Big Machine Radio Release Special)                                          28
# Fearless (Big Machine Radio Release Special)                                           26
# Fearless (Taylor's Version)                                                            26
# 1989 (Big Machine Radio Release Special)                                               26
# Midnights                                                                              26
# Speak Now (Deluxe Package)                                                             22
# Speak Now (Deluxe Edition)                                                             20
# Fearless (Platinum Edition)                                                            19
# Fearless Platinum Edition                                                              19
# Lover                                                                                  18
# Speak Now World Tour Live                                                              16
# Speak Now (Japanese Version)                                                           16
# Fearless (International Version)                                                       16
# reputation                                                                             15
# Speak Now (US Version)                                                                 14
# Live From Clear Channel Stripped 2008                                                   8
# Name: album, dtype: int64

# %%
df_no_karaoke['version'] = df_no_karaoke['album'].apply(lambda x: 'Original' if '(Taylor’s version)' not in x else 'Re-recorded')
# Out:
# /var/folders/ww/28hh0s1s76b6mw4gwsl64gn00000gn/T/ipykernel_13895/418775390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_karaoke['version'] = df_no_karaoke['album'].apply(lambda x: 'Original' if '(Taylor’s version)' not in x else 'Re-recorded')
# <bound method IndexOpsMixin.value_counts of 0       Original
# 1       Original
# 2       Original
# 3       Original
# 4       Original
#           ...
# 1232    Original
# 1233    Original
# 1234    Original
# 1235    Original
# 1236    Original
# Name: version, Length: 1075, dtype: object>

# %%
plt.figure(figsize=(10, 6))
sns.catplot(x='version', y='popularity', kind='box', data=df_no_karaoke, palette='Set2')
plt.title('Distribution of Popularity Scores for Original vs. Re-recorded Songs')
plt.xlabel('Album Version')
plt.ylabel('Popularity')
plt.show()

# %%
original_record_lm = ols('version ~ popularity', data=df_no_karaoke).fit()

#original_record_lm.summary()

p_value = original_record_lm.pvalues['popularity']
p_value
# Out:
# 0.41090972561631356

# %% [markdown]
# a) the boxplot does not show the taylors version, likely because there are very few taylor's version albums in the df
# b) the p-value is 0.41 which is greater than 0.05 and is thus not statistically significant, so there is little evidence to prove that popularity differs among re-recorded vs original albums

# %% [markdown]
# BONUS, worth up to 1 point: How would you determine whether [Taylor Swift has had an effect on the popularity of football](https://duckduckgo.com/?q=taylor+swift+football&atb=v314-1&ia=web)?  What data would you need?  What analysis would you perform?  What would you expect the results to be?

# %% [markdown]
# we would need audience attendance + viewership in major NFL games and create a linear regression on that vs whether or not Taylor Swift is performing on the same night. I would expect the results to be insignificant since the football and taylor swift attract a very different audience in general

# %% [markdown]
# ### Submit your completed assignment in both IPYNB and HTML formats.
